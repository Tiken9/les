# %%
import les
import random
import networkx as nx
import tsplib95 as lib
import numpy as np
import logging 
import random
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook 

logging.basicConfig(format="[%(asctime)s][%(levelname).1s][%(module)-25s] %(message)s")
# Out:
# [2023-03-22 15:37:19,744][D][pyplot                   ] Loaded backend module://matplotlib_inline.backend_inline version unknown.
# [2023-03-22 15:37:19,750][D][pyplot                   ] Loaded backend nbAgg version unknown.

# %%
problem = lib.load('dataset/gr17.tsp')
n = len(list(problem.get_nodes()))

# %%
G = problem.get_graph()
# nx.draw_networkx(G)

# %%
matrix = nx.to_numpy_matrix(G)
edges = {}
for i in range(n):
    for j in range(n):
        if j > i:
            edges[(i,j)] = matrix[i,j]
edges
# Out:
# {(0, 1): 633.0,
#  (0, 2): 257.0,
#  (0, 3): 91.0,
#  (0, 4): 412.0,
#  (0, 5): 150.0,
#  (0, 6): 80.0,
#  (0, 7): 134.0,
#  (0, 8): 259.0,
#  (0, 9): 505.0,
#  (0, 10): 353.0,
#  (0, 11): 324.0,
#  (0, 12): 70.0,
#  (0, 13): 211.0,
#  (0, 14): 268.0,
#  (0, 15): 246.0,
#  (0, 16): 121.0,
#  (1, 2): 390.0,
#  (1, 3): 661.0,
#  (1, 4): 227.0,
#  (1, 5): 488.0,
#  (1, 6): 572.0,
#  (1, 7): 530.0,
#  (1, 8): 555.0,
#  (1, 9): 289.0,
#  (1, 10): 282.0,
#  (1, 11): 638.0,
#  (1, 12): 567.0,
#  (1, 13): 466.0,
#  (1, 14): 420.0,
#  (1, 15): 745.0,
#  (1, 16): 518.0,
#  (2, 3): 228.0,
#  (2, 4): 169.0,
#  (2, 5): 112.0,
#  (2, 6): 196.0,
#  (2, 7): 154.0,
#  (2, 8): 372.0,
#  (2, 9): 262.0,
#  (2, 10): 110.0,
#  (2, 11): 437.0,
#  (2, 12): 191.0,
#  (2, 13): 74.0,
#  (2, 14): 53.0,
#  (2, 15): 472.0,
#  (2, 16): 142.0,
#  (3, 4): 383.0,
#  (3, 5): 120.0,
#  (3, 6): 77.0,
#  (3, 7): 105.0,
#  (3, 8): 175.0,
#  (3, 9): 476.0,
#  (3, 10): 324.0,
#  (3, 11): 240.0,
#  (3, 12): 27.0,
# ...

# %%
nx.to_numpy_matrix(G)
# Out:
# matrix([[  0., 633., 257.,  91., 412., 150.,  80., 134., 259., 505.,
#          353., 324.,  70., 211., 268., 246., 121.],
#         [633.,   0., 390., 661., 227., 488., 572., 530., 555., 289.,
#          282., 638., 567., 466., 420., 745., 518.],
#         [257., 390.,   0., 228., 169., 112., 196., 154., 372., 262.,
#          110., 437., 191.,  74.,  53., 472., 142.],
#         [ 91., 661., 228.,   0., 383., 120.,  77., 105., 175., 476.,
#          324., 240.,  27., 182., 239., 237.,  84.],
#         [412., 227., 169., 383.,   0., 267., 351., 309., 338., 196.,
#           61., 421., 346., 243., 199., 528., 297.],
#         [150., 488., 112., 120., 267.,   0.,  63.,  34., 264., 360.,
#          208., 329.,  83., 105., 123., 364.,  35.],
#         [ 80., 572., 196.,  77., 351.,  63.,   0.,  29., 232., 444.,
#          292., 297.,  47., 150., 207., 332.,  29.],
#         [134., 530., 154., 105., 309.,  34.,  29.,   0., 249., 402.,
#          250., 314.,  68., 108., 165., 349.,  36.],
# ...

# %%
random.seed(10)
sorted_edge = sorted(edges, key=edges.get)
i, delete = 0, 0
while kill < 3*n:
    _edge = sorted_edge[-i]
    if G.degree(_edge[0]) > n/2 and G.degree(_edge[1]) > n/2:
        G.remove_edge(_edge[0], _edge[1])
        delete+=1
        print('delete ', delete, _edge,'\n')
    i += 1

# %%
nx.draw_networkx(G)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.to_numpy_matrix(G)
# Out:
# matrix([[  0., 633., 257.,  91., 412., 150.,  80., 134., 259., 505.,
#          353., 324.,  70., 211., 268., 246., 121.],
#         [633.,   0., 390., 661., 227., 488., 572., 530., 555., 289.,
#          282., 638., 567., 466., 420., 745., 518.],
#         [257., 390.,   0., 228., 169., 112., 196., 154., 372., 262.,
#          110., 437., 191.,  74.,  53., 472., 142.],
#         [ 91., 661., 228.,   0., 383., 120.,  77., 105., 175., 476.,
#          324., 240.,  27., 182., 239., 237.,  84.],
#         [412., 227., 169., 383.,   0., 267., 351., 309., 338., 196.,
#           61., 421., 346., 243., 199., 528., 297.],
#         [150., 488., 112., 120., 267.,   0.,  63.,  34., 264., 360.,
#          208., 329.,  83., 105., 123., 364.,  35.],
#         [ 80., 572., 196.,  77., 351.,  63.,   0.,  29., 232., 444.,
#          292., 297.,  47., 150., 207., 332.,  29.],
#         [134., 530., 154., 105., 309.,  34.,  29.,   0., 249., 402.,
#          250., 314.,  68., 108., 165., 349.,  36.],
# ...

# %%
nx.degree(G)
# Out:
# DegreeView({0: 18, 1: 18, 2: 18, 3: 18, 4: 18, 5: 18, 6: 18, 7: 18, 8: 18, 9: 18, 10: 18, 11: 18, 12: 18, 13: 18, 14: 18, 15: 18, 16: 18})

# %% [markdown]
# $$c(x) = \sum_{i,j}w_{i,j}\sum_p x_{i,p}x_{j,p+1}$$
# $$\sum_ix_{i,p}=1$$
# $$\sum_px_{i,p}=1$$
